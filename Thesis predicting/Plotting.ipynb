# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(15, 5))
ax = fig.add_subplot(111)
ax.plot([128, 112, 117, 103, 65, 149, 148, 149, 153, 152],
        [9.097, 4.512, 9.301, 4.535, 8.739, 8.846, 2.667, 8.385, 2.846, 2.951])

plt.ylabel('DCM')
plt.xlabel('Heart rate')

x = [128, 112, 117, 103, 65, 149, 148, 149, 153, 152]
y = [9.097, 4.512, 9.301, 4.535, 8.739, 8.846, 2.667, 8.385, 2.846, 2.951]
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
#plt.plot(x,p(x))
plt.show()

# %%
fig = plt.figure(figsize=(15, 5))
ax = fig.add_subplot(111)
ax.plot([59, 102, 105, 107, 118, 147, 188, 188, 257, 260, 326, 420], 
        [6.54, 4.64, 5.92, 5.03, 7.02, 5.47, 5.95, 5.27, 7.69, 4.05, 6.25, 4.19])

x = [59, 102, 105, 107, 118, 147, 188, 188, 257, 260, 326, 420]
y = [6.54, 4.64, 5.92, 5.03, 7.02, 5.47, 5.95, 5.27, 7.69, 4.05, 6.25, 4.19]
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")
plt.ylabel('DCM')
plt.xlabel('Impulse')
plt.show()
